# %% [markdown]
# # Task3: Visualization using Histogram

# %% [markdown]
# Name: Akshada Uttam Baad

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset from a CSV file (replace 'data.csv' with your file path)
df = pd.read_csv('D:\software\python\Datasets\Iris.csv')

# Extract the data from the DataFrame
data = df['SepalLengthCm']

# Create a histogram
plt.figure(figsize=(8, 6))
plt.hist(data, bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('SepalLengthCm')
plt.title('Histogram of Data Distribution')

# Show the histogram
plt.show()
